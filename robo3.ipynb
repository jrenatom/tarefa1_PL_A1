# %% [markdown]
# <a href="https://colab.research.google.com/github/jrenatom/tarefa1_PL_A1/blob/main/robo3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scrapy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 264 kB 4.0 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 51.3 MB/s
# ...
#      |████████████████████████████████| 55 kB 3.9 MB/s
# ...
#      |████████████████████████████████| 93 kB 2.0 MB/s
# ...
#      |████████████████████████████████| 251 kB 50.2 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 33.6 MB/s
# ...
#      |████████████████████████████████| 74 kB 3.0 MB/s
# ...
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.6-py3-none-any.whl size=11958 sha256=d2db11ecc91bd54a40a0d9bbd6760e815447e3c689c6804b46afbf9058b1e3b8
#   Stored in directory: /root/.cache/pip/wheels/c9/d6/6a/de198d890277cde60ca3dbebe7ae592d3b381c7d9bb2455f4d
# Successfully built PyDispatcher
# ...

# %%
# !pwd
# !ls -l
# Out:
# /content
# total 12
# drwxr-xr-x 2 root root 4096 Sep 21 13:41 robo_aj
# drwxr-xr-x 1 root root 4096 Sep 14 13:44 sample_data
# -rw-r--r-- 1 root root  256 Sep 21 13:40 scrapy.cfg

# %%
# !ls -l
# Out:
# total 12
# drwxr-xr-x 2 root root 4096 Sep 21 13:41 robo_aj
# drwxr-xr-x 1 root root 4096 Sep 14 13:44 sample_data
# -rw-r--r-- 1 root root  256 Sep 21 13:40 scrapy.cfg

# %%
# !scrapy runspider ./robo_aj/robo_aj/spiders/spider_aj.py
# Out:
# 2022-09-21 13:51:04 [scrapy.utils.log] INFO: Scrapy 2.6.2 started (bot: scrapybot)
# 2022-09-21 13:51:04 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.14, cssselect 1.1.0, parsel 1.6.0, w3lib 2.0.1, Twisted 22.8.0, Python 3.7.14 (default, Sep  8 2022, 00:06:44) - [GCC 7.5.0], pyOpenSSL 22.0.0 (OpenSSL 3.0.5 5 Jul 2022), cryptography 38.0.1, Platform Linux-5.10.133+-x86_64-with-Ubuntu-18.04-bionic
# 2022-09-21 13:51:04 [scrapy.crawler] INFO: Overridden settings:
# {'SPIDER_LOADER_WARN_ONLY': True}
# 2022-09-21 13:51:04 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2022-09-21 13:51:04 [scrapy.extensions.telnet] INFO: Telnet Password: 006d8e068d08687b
# 2022-09-21 13:51:04 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# ...
